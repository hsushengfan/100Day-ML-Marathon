# %% [markdown]
# ## 作業一
#
#
# 我所選的資料  https://www.kaggle.com/lava18/google-play-store-apps#googleplaystore.csv
# 1. 你選的這組資料為何重要這組資料包含了在google play商店中，所有的App的屬性、種類是否需要付費以及下載人數等資訊，這能有像的幫助所有希望在google play商店上架或希望上架的廠商能更了解這個市場的樣貌，也能提供未來希望進入這個市場的人非常重要的參考。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)資料是透過從google play商店中爬取公開的數據獲得。
# 3. 蒐集而來的資料型態為何蒐集資料包括了結構化的下載數量、用戶評分、檔案大小等等而非結構化的資料則包括了App本身在google play商店中的分類、上次更新的時間點等等。
# 4. 這組資料想解決的問題如何評估例如可以透過app的檔案大小、分類以及是否免費，取回歸來對於下載量進行預測
#
# ## 作業二
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 核心問題應該為，如何提升公司的總業績，定義則為，同一時間區段內，要將公司總體獲得的總收入金額提高。而總收入金額為所有司機的載客趟數乘上每趟獲得的酬勞，因此若要提升業績，應該要透過提升載客趟數以及每趟所獲得的酬勞來著手。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 資料應該可以由司機載客時的跳表機可得，可以獲得在不同時間點、地點、載客的人數、趟數、以及每趟所行使的距離、時間、獲得酬勞等資訊，而這樣的資料好處是易於取得，壞處是無法獲得是廠商其他競爭對手的狀態，可能無法對市場全貌進行預測，或會產生偏誤而沒有發現目前未被納入自己客群的潛力消費者。
#
# 3. 蒐集而來的資料型態為何
# 應同時包含結構化以及非結構化的資料，在載客人數、趟數以及金額上可以有數字的呈現，但地點時間點等資訊就只能用文字呈現
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 舉例來說，可以透過分析不同時間點在每個地區是否會有大量的載客需求出現，能預先讓車隊的車輛先行去等待，那我們就能透過未來實際地區的表現來修正我們的預估模型。
#
#
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    mse = sum((y - y_hat)**2) / len(y)
    return mse

# %%
 def mean_absolute_error(y, y_hat):
    mae = sum(abs(y - y_hat)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)

print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 221.871
# The Mean absolute error is 11.947
